# %% [markdown]
# <div align="center"><img src="img/2013-1.png" width="70%"></div>

# %% [markdown]
# $$
# \mbox{Coin Flip}=
# \left\{\begin{array}{ll}
# \mbox{Success}&\mbox{with probability}\quad \frac{1}{8}\\
# \mbox{Failure}&\mbox{with probability}\quad \frac{7}{8}\\
# \end{array}\right.
# $$
# $$$$
# $$
# X\sim Geo\left(\frac{7}{8}\right)
# $$

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
y = np.linspace(0,10,100)
F_y = 1-np.exp(-y/2)
plt.plot(y,F_y)
plt.xlim([0,10])
plt.ylim([0,1])
plt.grid(True)
plt.title('CDF')
plt.show()
